# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from IPython import display

# %matplotlib inline

# %%
sort_data = pd.read_csv('tmp.csv')
sort_data.head(5)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.601267  0.773575  0.976506  0.298141  0.224480  0.769064  0.921245
# 1  0.601267  0.298141  0.976506  0.773575  0.921245  0.769064  0.224480
# 2  0.298141  0.601267  0.773575  0.976506  0.921245  0.769064  0.274584
# 3  0.298141  0.601267  0.274584  0.224480  0.921245  0.769064  0.773575
# 4  0.274584  0.224480  0.298141  0.601267  0.773575  0.769064  0.921245
#
#           7         8         9  ...        54        55        56        57  \
# 0  0.274584  0.332273  0.781215  ...  0.955016  0.323328  0.565198  0.834971
# 1  0.274584  0.332273  0.589301  ...  0.157052  0.323328  0.513065  0.190205
# 2  0.224480  0.332273  0.589301  ...  0.323328  0.157052  0.190205  0.513065
# 3  0.976506  0.640511  0.640251  ...  0.590863  0.613018  0.980347  0.513065
# 4  0.976506  0.781215  0.929783  ...  0.955016  0.613018  0.980347  0.834971
#
#          58        59        60        61       62        63
# 0  0.513065  0.190205  0.231143  0.980347  0.16907  0.146705
# 1  0.565198  0.834971  0.231143  0.980347  0.16907  0.146705
# 2  0.565198  0.834971  0.980347  0.231143  0.16907  0.146705
# 3  0.565198  0.834971  0.190205  0.231143  0.16907  0.146705
# 4  0.565198  0.513065  0.190205  0.231143  0.16907  0.146705
#
# [5 rows x 64 columns]

# %%
plt.figure(figsize=(18, 10))
ind = [x for x in range(64)]

#TODO: add separate plots for separate threads
# row_idx = []

# for ct in range(4):
#     row_idx.append([])
#     for i in range(0, 64, 4):
#         row_idx[ct].append((ct+i)%64)
        
# print(row_idx)


for idx, row in sort_data.iterrows():
    sns.barplot(x=ind, y=row)
    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(0.1)
    plt.clf()
